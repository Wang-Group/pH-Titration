# %%
from pathlib import Path
import subprocess, sys
PROFILE = "standard"  # quick, standard, or full
DEVICE = "auto"       # auto, cpu, cuda, or cuda:0
root = Path.cwd()
output = root / "results" / f"{PROFILE}_run"
subprocess.run([sys.executable, "run_pipeline.py", "--profile", PROFILE, "--output-dir", str(output), "--device", DEVICE, "--resume"], check=True)
