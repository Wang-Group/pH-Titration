# %%
from pathlib import Path
import subprocess, sys
QUICK = False
root = Path.cwd()
if QUICK:
    command = [sys.executable, "bayesian_external_rule_ablation.py", "--output-dir", str(root / "results" / "bayesian_rule_ablation_quick"), "--seeds", "101", "--tasks-per-seed", "50", "--particles", "100", "--resume"]
else:
    command = [sys.executable, "bayesian_external_rule_ablation.py", "--output-dir", str(root / "results" / "bayesian_rule_ablation_standard"), "--seeds", "101", "202", "303", "404", "555", "--tasks-per-seed", "3000", "--particles", "1000", "--resume"]
subprocess.run(command, check=True)
